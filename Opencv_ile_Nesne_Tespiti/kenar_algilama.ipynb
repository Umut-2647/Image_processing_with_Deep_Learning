# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('media/london.jpeg',0)
plt.figure() ,plt.imshow(img, cmap='gray'), plt.axis('off')
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x29c553ef2f0>,
#  (-0.5, 639.5, 359.5, -0.5))

# %%
edges = cv2.Canny(image=img , threshold1=0,threshold2=255)
plt.figure() ,plt.imshow(edges, cmap='gray'), plt.axis('off')
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x29c55a250a0>,
#  (-0.5, 639.5, 359.5, -0.5))

# %%
med_val = np.median(img) #resmin median değeri(threshold icin)
print(med_val)

low = int(max(0,(1-0.33)*med_val))
high = int(min(255,(1+0.33)*med_val))

print(low)
print(high)

edges = cv2.Canny(image=img , threshold1=low,threshold2=high)
plt.figure() ,plt.imshow(edges, cmap='gray'), plt.axis('off')
# Out:
# 71.0
# 47
# 94
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x29c5538ad20>,
#  (-0.5, 639.5, 359.5, -0.5))

# %%
#blur uygulayarak daha iyi sonuç alabiliriz

blurred_img = cv2.blur(img, ksize=(7,7))
plt.figure() ,plt.imshow(blurred_img, cmap='gray'), plt.axis('off')
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x29c5a5e0ef0>,
#  (-0.5, 639.5, 359.5, -0.5))

# %%
med_val = np.median(blurred_img) #resmin median değeri(threshold icin)
print(med_val)

low = int(max(0,(1-0.33)*med_val))
high = int(min(255,(1+0.33)*med_val))

print(low)
print(high)


edges = cv2.Canny(image=blurred_img , threshold1=low,threshold2=high)
plt.figure() ,plt.imshow(edges, cmap='gray'), plt.axis('off')
# Out:
# 72.0
# 48
# 95
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x29c5a5e23c0>,
#  (-0.5, 639.5, 359.5, -0.5))
