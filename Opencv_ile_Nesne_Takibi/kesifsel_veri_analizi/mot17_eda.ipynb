# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import time
import seaborn as sns

#frame numarasi,kimlik numarasi,sol,ust,genislik,yukseklik,skor,sinif,gorunurluk

col_list = ["frame_number","identity_number","left","top","width","height","score","class","visibility"]

data = pd.read_csv("gt.txt",names=col_list) #gt.txt dosyasi okunuyor ve sutunlara isimler veriliyor

plt.figure()
sns.countplot(x='class', data=data) #kullanimi degismis!!
plt.show() #siniflarin sayilarini gosteren grafik

video_path = "MOT17-13-SDP.mp4"

cap = cv2.VideoCapture(video_path) #video okunuyor
